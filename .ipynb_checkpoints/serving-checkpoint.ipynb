# %%
import bentoml

# %%
# !/opt/anaconda3/bin/bentoml serve service.py:lgbm_italy_service --reload --host 0.0.0.0 --port 3005
# Out:
# 2023-04-08T12:36:02+0200 [INFO] [cli] Starting development BentoServer from "service.py:lgbm_italy_service" running on http://0.0.0.0:3005 (Press CTRL+C to quit)
# 2023-04-08 12:36:02 circus[1308550] [INFO] Loading the plugin...
# 2023-04-08 12:36:02 circus[1308550] [INFO] Endpoint: 'tcp://127.0.0.1:48109'
# 2023-04-08 12:36:02 circus[1308550] [INFO] Pub/sub: 'tcp://127.0.0.1:56047'
# 2023-04-08T12:36:02+0200 [INFO] [observer] Watching directories: ['/new_vol_300/marija/conda/multiusers/iccs/model_serving/LightGBM_italy_serving', '/new_vol_300/marija/conda/multiusers/iccs/bentoml/models']
# 2023/04/08 12:36:10 WARNING mlflow.pyfunc: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - darts (current: 0.23.1, required: darts==0.22.0)
#  - torch (current: 1.11.0, required: torch==1.11.0+cu102)
#  - mlflow (current: 1.27.0, required: mlflow==1.25.1)
# ...

# %% [markdown]
# ## Run it in the notebook Make_predictions.ipynb that is created in this same folder

# %%
# !/opt/anaconda3/bin/bentoml build
# Out:
# Building BentoML service "lgbm_italy:qtlcdcgv7gad56qw" from build context "/new_vol_300/marija/conda/multiusers/iccs/model_serving/LightGBM_italy_serving"
# Packing model "lgbm_italy:b2xpt4wsbw7m76qw"
# Locking PyPI package versions..
# WARNING:pip._internal.metadata.base:Ignoring invalid distribution - (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING:pip._internal.metadata.base:Ignoring invalid distribution -arts (/opt/anaconda3/lib/python3.9/site-packages)
#
# ██████╗░███████╗███╗░░██╗████████╗░█████╗░███╗░░░███╗██╗░░░░░
# ██╔══██╗██╔════╝████╗░██║╚══██╔══╝██╔══██╗████╗░████║██║░░░░░
# ██████╦╝█████╗░░██╔██╗██║░░░██║░░░██║░░██║██╔████╔██║██║░░░░░
# ██╔══██╗██╔══╝░░██║╚████║░░░██║░░░██║░░██║██║╚██╔╝██║██║░░░░░
# ██████╦╝███████╗██║░╚███║░░░██║░░░╚█████╔╝██║░╚═╝░██║███████╗
# ╚═════╝░╚══════╝╚═╝░░╚══╝░░░╚═╝░░░░╚════╝░╚═╝░░░░░╚═╝╚══════╝
#
# Successfully built Bento(tag="lgbm_italy:qtlcdcgv7gad56qw")

# %% [markdown]
# ## We then run in the terminal:|

# %%
#sudo su
#export BENTOML_HOME=/new_vol_300/marija/conda/multiusers/iccs/bentoml
#/opt/anaconda3/bin/bentoml containerize lgbm_italy:qtlcdcgv7gad56qw
#docker run -it --rm -p 3005:3000 lgbm_italy:qtlcdcgv7gad56qw
